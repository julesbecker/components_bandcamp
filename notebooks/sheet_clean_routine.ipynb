# %% [markdown]
# Notebook for preparing edge sheet from network-graph.csv

# %%
import csv
import json
import pandas as pd
from itertools import chain, combinations
from collections import Counter
import functools
import operator
from tqdm.notebook import tqdm

# %%
# set pandas display options
pd.set_option("display.max_rows", 500)
pd.set_option('display.max_colwidth', 500)
pd.set_option("display.max_columns", 200)

# %%
conv_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/network-graph.csv"
edge_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/edge_sheet.csv"
node_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/node_sheet.csv"

# %%
album_data = pd.read_csv(conv_file)

# %% [markdown]
# # 1. Produce edge_sheet.csv from network-graph.csv

# %%
# global tallying, edges
grouped = album_data.groupby('standard_name')
Collected = pd.DataFrame(columns =['genre1', 'genre2','count','location'])

for place, group in grouped:
    edge_list = []
    genre_list = group['genre']
    for item in genre_list:
        genres_in_list = sorted(list(item.split(",")))
        genre_combs = combinations(genres_in_list, 2)
        # return list of tuples
        for combination in genre_combs:
            edge_list.append([combination])
    edge_tally = Counter(chain(*edge_list))

    edge_tallies_dict = dict(edge_tally)

    edgeprep_dataframe = pd.DataFrame.from_dict(edge_tallies_dict, orient='index')
    edgeprep_dataframe.rename(columns = {0:'count'}, inplace = True) 
    edgeprep_dataframe['genre_pair'] = edgeprep_dataframe.index
    edgeprep_dataframe['row'] = edgeprep_dataframe.reset_index().index
    edgeprep_dataframe = edgeprep_dataframe.set_index(['row'])

    genre_edges = pd.DataFrame(list(edgeprep_dataframe['genre_pair']), columns =['genre1', 'genre2']) 

    count = edgeprep_dataframe['count']
    genre_edges = genre_edges.join(count)
    genre_edges['location'] = place
    Collected = Collected.append(genre_edges)

# %%
Collected.to_csv(edge_file, index=False)

# %%
Collected.head()
# Out:
#        genre1       genre2 count                location
# 0         ebm   electronic    28  Adelaide SA, Australia
# 1         ebm  electronica    23  Adelaide SA, Australia
# 2         ebm   industrial    27  Adelaide SA, Australia
# 3  electronic  electronica    61  Adelaide SA, Australia
# 4  electronic   industrial    27  Adelaide SA, Australia

# %% [markdown]
# # 2. produce json file from the edge and node sheet

# %%
json_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/data/network_graph.json"

# %%
with open(json_file, "r") as jsonFile:
    json_output = json.load(jsonFile)
node_reader = pd.read_csv(node_file)

# idea - 
for row in node_reader.itertuples():
    place_obj = {'n':[], 'l':[]}
    place_matches = [obj for obj in json_output if obj['ct'] == row.location]
    if not place_matches:
        print("NEW PLACE:", row.location)
        place_obj['ct'] = row.location
        place_obj['cor'] = [row.lng, row.lat]
        json_output.append(place_obj)
    elif place_matches:
        place_obj = place_matches[0]
    place_obj["n"].append({"g":row.genre,"c":row.count,"r":round(row.relative, 3)})

link_reader = pd.read_csv(edge_file)
for row in link_reader.itertuples():
    place_matches = [obj for obj in json_output if obj['ct'] == row.location]
    place_obj = place_matches[0]
    place_obj["l"].append({"g1":row.genre1,"g2":row.genre2,"c":row.count})

with open(json_file, "w") as jsonFile:
    json.dump(json_output, jsonFile, separators=(',', ':'))
# Out:
# NEW PLACE: Adelaide SA, Australia
# NEW PLACE: Albuquerque, NM, USA
# NEW PLACE: Amsterdam, Netherlands
# NEW PLACE: Antwerp, Belgium
# NEW PLACE: Asheville, NC, USA
# NEW PLACE: Athens, GA, USA
# NEW PLACE: Athens, Greece
# NEW PLACE: Atlanta, GA, USA
# NEW PLACE: Auckland, New Zealand
# NEW PLACE: Austin, TX, USA
# NEW PLACE: Baltimore, MD, USA
# NEW PLACE: Barcelona, Spain
# NEW PLACE: Belfast, UK
# NEW PLACE: Belgrade, Serbia
# NEW PLACE: Berkeley, CA, USA
# NEW PLACE: Berlin, Germany
# NEW PLACE: Birmingham, UK
# NEW PLACE: Bogota, Colombia
# NEW PLACE: Bologna, Metropolitan City of Bologna, Italy
# NEW PLACE: Bordeaux, France
# NEW PLACE: Boston, MA, USA
# NEW PLACE: Boulder, CO, USA
# NEW PLACE: Brighton, UK
# NEW PLACE: Brisbane QLD, Australia
# NEW PLACE: Bristol, UK
# NEW PLACE: Brooklyn, NY, USA
# NEW PLACE: Brussels, Belgium
# NEW PLACE: Bucharest, Romania
# NEW PLACE: Budapest, Hungary
# NEW PLACE: Buenos Aires, Argentina
# NEW PLACE: Buffalo, NY, USA
# NEW PLACE: Calgary, AB, Canada
# NEW PLACE: Cape Town, South Africa
# NEW PLACE: Cardiff, UK
# NEW PLACE: Charlotte, NC, USA
# NEW PLACE: Chicago, IL, USA
# NEW PLACE: Cincinnati, OH, USA
# NEW PLACE: Cleveland, OH, USA
# NEW PLACE: Cologne, Germany
# NEW PLACE: Columbus, OH, USA
# NEW PLACE: Copenhagen, Denmark
# NEW PLACE: Dallas, TX, USA
# NEW PLACE: Dayton, OH, USA
# NEW PLACE: Denver, CO, USA
# NEW PLACE: Detroit, MI, USA
# NEW PLACE: Dresden, Germany
# NEW PLACE: Dublin, Ireland
# NEW PLACE: Durham, NC, USA
# NEW PLACE: Düsseldorf, Germany
# NEW PLACE: Edinburgh, UK
# NEW PLACE: Edmonton, AB, Canada
# NEW PLACE: Frankfurt, Germany
# NEW PLACE: Geneva, Switzerland
# NEW PLACE: Ghent, Belgium
# NEW PLACE: Glasgow, UK
# NEW PLACE: Gothenburg, Sweden
# NEW PLACE: Grenoble, France
# NEW PLACE: Hamburg, Germany
# NEW PLACE: Hamilton, ON, Canada
# NEW PLACE: Helsinki, Finland
# NEW PLACE: Hong Kong
# NEW PLACE: Houston, TX, USA
# NEW PLACE: Indianapolis, IN, USA
# NEW PLACE: Johannesburg, South Africa
# NEW PLACE: Kansas City, MO, USA
# NEW PLACE: Kyiv, Ukraine, 02000
# NEW PLACE: Las Vegas, NV, USA
# NEW PLACE: Lausanne, Switzerland
# NEW PLACE: Leeds, UK
# NEW PLACE: Leicester, UK
# NEW PLACE: Leipzig, Germany
# NEW PLACE: Lille, France
# NEW PLACE: Lima, Peru
# NEW PLACE: Lisbon, Portugal
# NEW PLACE: Liverpool, UK
# NEW PLACE: London, UK
# NEW PLACE: Long Beach, CA, USA
# NEW PLACE: Los Angeles, CA, USA
# NEW PLACE: Louisville, KY, USA
# NEW PLACE: Lyon, France
# NEW PLACE: Madison, WI, USA
# NEW PLACE: Madrid, Spain
# NEW PLACE: Malmö, Sweden
# NEW PLACE: Manchester, UK
# NEW PLACE: Marseille, France
# NEW PLACE: Melbourne VIC, Australia
# NEW PLACE: Memphis, TN, USA
# NEW PLACE: Mexico City, CDMX, Mexico
# NEW PLACE: Miami, FL, USA
# NEW PLACE: Milan, Metropolitan City of Milan, Italy
# NEW PLACE: Milwaukee, WI, USA
# NEW PLACE: Minneapolis, MN, USA
# NEW PLACE: Montreal, QC, Canada
# NEW PLACE: Moscow, Russia
# NEW PLACE: Munich, Germany
# NEW PLACE: Nantes, France
# NEW PLACE: Nashville, TN, USA
# NEW PLACE: New Orleans, LA, USA
# NEW PLACE: New York, NY, USA
# NEW PLACE: Newcastle upon Tyne, UK
# NEW PLACE: Nijmegen, Netherlands
# NEW PLACE: Nottingham, UK
# NEW PLACE: Oakland, CA, USA
# NEW PLACE: Olympia, WA, USA
# NEW PLACE: Omaha, NE, USA
# NEW PLACE: Orlando, FL, USA
# NEW PLACE: Oslo, Norway
# NEW PLACE: Ottawa, ON, Canada
# NEW PLACE: Paris, France
# NEW PLACE: Perth WA, Australia
# NEW PLACE: Philadelphia, PA, USA
# NEW PLACE: Phoenix, AZ, USA
# NEW PLACE: Pittsburgh, PA, USA
# NEW PLACE: Portland, OR, USA
# NEW PLACE: Porto, Portugal
# NEW PLACE: Prague, Czechia
# NEW PLACE: Providence, RI, USA
# NEW PLACE: Queens, NY, USA
# NEW PLACE: Raleigh, NC, USA
# NEW PLACE: Rennes, France
# NEW PLACE: Reykjavík, Iceland
# NEW PLACE: Richmond, VA, USA
# NEW PLACE: Rio de Janeiro, State of Rio de Janeiro, Brazil
# NEW PLACE: Rochester, NY, USA
# NEW PLACE: Rome, Metropolitan City of Rome, Italy
# NEW PLACE: Rotterdam, Netherlands
# NEW PLACE: Sacramento, CA, USA
# NEW PLACE: Salt Lake City, UT, USA
# NEW PLACE: San Antonio, TX, USA
# NEW PLACE: San Diego, CA, USA
# NEW PLACE: San Francisco, CA, USA
# NEW PLACE: San Jose, CA, USA
# NEW PLACE: Santa Cruz, CA, USA
# NEW PLACE: Santiago, Santiago Metropolitan Region, Chile
# NEW PLACE: Seattle, WA, USA
# NEW PLACE: Seoul, South Korea
# NEW PLACE: Sheffield, UK
# NEW PLACE: Singapore
# NEW PLACE: St Petersburg, Russia
# NEW PLACE: St. Louis, MO, USA
# NEW PLACE: Stockholm, Sweden
# NEW PLACE: Sydney NSW, Australia
# NEW PLACE: São Paulo, State of São Paulo, Brazil
# NEW PLACE: Tampa, FL, USA
# NEW PLACE: Tbilisi, Georgia
# NEW PLACE: Tel Aviv-Yafo, Israel
# NEW PLACE: The Hague, Netherlands
# NEW PLACE: Thessaloniki, Greece
# NEW PLACE: Tokyo, Japan
# NEW PLACE: Toronto, ON, Canada
# NEW PLACE: Toulouse, France
# NEW PLACE: Tucson, AZ, USA
# NEW PLACE: Utrecht, Netherlands
# NEW PLACE: Valencia, Spain
# NEW PLACE: Vancouver, BC, Canada
# NEW PLACE: Victoria, BC, Canada
# NEW PLACE: Vienna, Austria
# NEW PLACE: Vilnius, Lithuania
# NEW PLACE: Warsaw, Poland
# NEW PLACE: Washington, DC, USA
# NEW PLACE: Wellington, New Zealand
# NEW PLACE: Winnipeg, MB, Canada
# NEW PLACE: Zagreb, Croatia
# NEW PLACE: Zürich, Switzerland
# NEW PLACE: İstanbul, Turkey
