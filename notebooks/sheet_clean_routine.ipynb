# %% [markdown]
# Notebook for preparing edge sheet from network-graph.csv

# %%
import csv
import json
import pandas as pd
from itertools import chain, combinations
from collections import Counter
import functools
import operator
from tqdm.notebook import tqdm

# %%
# set pandas display options
pd.set_option("display.max_rows", 500)
pd.set_option('display.max_colwidth', 500)
pd.set_option("display.max_columns", 200)

# %%
conv_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/network-graph_extended.csv"
edge_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/edge_sheet.csv"
node_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/notebooks/node_sheet.csv"

# %%
album_data = pd.read_csv(conv_file)

# %% [markdown]
# # 1. Produce edge_sheet.csv from network-graph.csv

# %%
# global tallying, edges
grouped = album_data.groupby('standard_name')
Collected = pd.DataFrame(columns =['genre1', 'genre2','count','location'])

for place, group in grouped:
    edge_list = []
    genre_list = group['genre']
    for item in genre_list:
        genres_in_list = sorted(list(item.split(",")))
        # need to figure out which genres appear most between both columns
        genre_combs = combinations(genres_in_list, 2)
        # return list of tuples
        for combination in genre_combs:
            edge_list.append([combination])
    edge_tally = Counter(chain(*edge_list))

    edge_tallies_dict = dict(edge_tally)

    edgeprep_dataframe = pd.DataFrame.from_dict(edge_tallies_dict, orient='index')
    edgeprep_dataframe.rename(columns = {0:'count'}, inplace = True) 
    edgeprep_dataframe['genre_pair'] = edgeprep_dataframe.index
    edgeprep_dataframe['row'] = edgeprep_dataframe.reset_index().index
    edgeprep_dataframe = edgeprep_dataframe.set_index(['row'])

    genre_edges = pd.DataFrame(list(edgeprep_dataframe['genre_pair']), columns =['genre1', 'genre2']) 

    count = edgeprep_dataframe['count']
    genre_edges = genre_edges.join(count)
    genre_edges['location'] = place
    Collected = Collected.append(genre_edges)
    
Collected
# Out:
#             genre1       genre2 count                location
# 0          ambient  atmospheric    18  Adelaide SA, Australia
# 1          ambient  electronica    29  Adelaide SA, Australia
# 2      atmospheric  electronica    10  Adelaide SA, Australia
# 3              ebm   electronic    28  Adelaide SA, Australia
# 4              ebm  electronica    23  Adelaide SA, Australia
# ...            ...          ...   ...                     ...
# 1155         space       stoner     1        İstanbul, Turkey
# 1156         space  stoner rock     1        İstanbul, Turkey
# 1157       ambient   industrial     1        İstanbul, Turkey
# 1158       ambient       techno     1        İstanbul, Turkey
# 1159  experimental   soundscape     1        İstanbul, Turkey
#
# [382722 rows x 4 columns]

# %%
Collected.to_csv(edge_file, index=False)

# %%
grouped.head()
# Out:
#                  standard_name  \
# 0       Adelaide SA, Australia
# 1       Adelaide SA, Australia
# 2       Adelaide SA, Australia
# 3       Adelaide SA, Australia
# 4       Adelaide SA, Australia
# ...                        ...
# 525676        İstanbul, Turkey
# 525677        İstanbul, Turkey
# 525678        İstanbul, Turkey
# 525679        İstanbul, Turkey
# 525680        İstanbul, Turkey
#
#                                                                       genre
# 0                                           atmospheric,electronica,ambient
# 1                                     electronic,industrial,ebm,electronica
# 2                                     electronica,industrial,ebm,electronic
# 3                                     electronica,ebm,industrial,electronic
# 4                                     industrial,electronic,electronica,ebm
# ...                                                                     ...
# 525676                                            bass,ambient,experimental
# 525677                                                           electronic
# 525678                                                           electronic
# 525679        electroacoustic,electronic,experimental,improvisation,ambient
# 525680  electronic,electroacoustic,experimental,improvisation,ambient,drone
#
# [875 rows x 2 columns]

# %%
# produce id json
df1 = pd.DataFrame(Collected['genre1'].value_counts())
df2 = pd.DataFrame(Collected['genre2'].value_counts())
dfc = pd.concat([df1, df2], axis=1, sort=False)
dfc["total"] = dfc.sum(axis=1)
dfc = dfc.sort_values(['total'], ascending = (False))
dfc['name'] = dfc.index
dfc = dfc.reset_index()
# id_df

alias_json = []
alias_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/data/ng_ids.json"
with open(alias_file, "r") as jsonFile:
    json_output = json.load(jsonFile)
for i, row in dfc.iterrows():
    id_obj = {}
    id_obj['i'] = i#.astype(int)
    id_obj['g'] = row[0]
    alias_json.append(id_obj)

# %%
# whoops, turn id json into dict
alias_obj = {}
alias_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/data/ng_ids.json"
# for i, row in dfc.iterrows():

with open(alias_file, "r") as jsonFile:
    json_output = json.load(jsonFile)
protodict = dfc['name'].to_dict()
with open(alias_file, "w") as jsonFile:
    json.dump(protodict, jsonFile, separators=(',', ':'))

# %%
protodict
# Out:
# {0: 'electronic',
#  1: 'experimental',
#  2: 'ambient',
#  3: 'rock',
#  4: 'alternative',
#  5: 'pop',
#  6: 'rap/hip hop',
#  7: 'indie',
#  8: 'lo fi',
#  9: 'instrumental',
#  10: 'punk',
#  11: 'techno',
#  12: 'psychedelic',
#  13: 'house',
#  14: 'jazz',
#  15: 'metal',
#  16: 'electronica',
#  17: 'folk',
#  18: 'indie rock',
#  19: 'noise',
#  20: 'funk',
#  21: 'electro',
#  22: 'dance',
#  23: 'soundtrack',
#  24: 'soul',
#  25: 'industrial',
#  26: 'post punk',
#  27: 'downtempo',
#  28: 'drone',
#  29: 'acoustic',
#  30: 'indie pop',
#  31: 'world',
#  32: 'bass',
#  33: 'synthpop',
#  34: 'beats',
#  35: 'synthwave',
#  36: 'post rock',
#  37: 'synth',
#  38: 'hardcore',
#  39: 'singer songwriter',
#  40: 'shoegaze',
#  41: 'alternative rock',
#  42: 'dub',
#  43: 'dark ambient',
#  44: 'experimental electronic',
#  45: 'idm',
#  46: 'r & b',
#  47: 'deep house',
#  48: 'drum & bass',
#  49: 'disco',
#  50: 'dream pop',
#  51: 'garage',
#  52: 'progressive',
#  53: 'chill',
#  54: 'avant garde',
#  55: 'darkwave',
#  56: 'new wave',
#  57: 'trap',
#  58: 'blues',
#  59: 'minimal',
#  60: 'punk rock',
#  61: 'guitar',
#  62: 'doom',
#  63: 'acid',
#  64: 'psychedelic rock',
#  65: 'dubstep',
#  66: 'trip hop',
#  67: 'chillout',
#  68: 'black metal',
#  69: 'piano',
#  70: 'rock & roll',
#  71: 'classical',
#  72: 'breaks',
#  73: 'breakbeat',
#  74: 'indie folk',
#  75: 'dark',
#  76: 'emo',
#  77: 'hiphop',
#  78: 'progressive rock',
#  79: 'reggae',
#  80: 'remix',
#  81: 'edm',
#  82: 'atmospheric',
#  83: 'death metal',
#  84: 'diy',
#  85: 'vaporwave',
#  86: 'garage rock',
#  87: 'jungle',
#  88: 'folk rock',
#  89: '80s',
#  90: 'soundscape',
#  91: 'ambient electronic',
#  92: 'americana',
#  93: 'hard rock',
#  94: 'cinematic',
#  95: 'goth',
#  96: 'country',
#  97: 'grunge',
#  98: 'improvisation',
#  99: 'heavy metal',
#  100: 'trance',
#  101: 'new age',
#  102: 'instrumental hip hop',
#  103: 'r & b/soul',
#  104: 'doom metal',
#  105: 'nu disco',
#  106: 'ebm',
#  107: 'tech house',
#  108: 'pop punk',
#  109: 'noise rock',
#  110: 'post hardcore',
#  111: 'chillwave',
#  112: 'pop rock',
#  113: 'underground',
#  114: 'power pop',
#  115: 'electropop',
#  116: 'psych',
#  117: 'stoner rock',
#  118: 'rave',
#  119: 'glitch',
#  120: 'deep',
#  121: 'bedroom pop',
#  122: 'retrowave',
#  123: 'sludge',
#  124: 'latin',
#  125: 'video game music',
#  126: 'progressive metal',
#  127: 'club',
#  128: 'underground hip hop',
#  129: 'hardcore punk',
#  130: 'fusion',
#  131: 'math rock',
#  132: 'alt country',
#  133: 'meditation',
#  134: 'spoken word',
#  135: 'edits',
#  136: 'art rock',
#  137: 'boom bap',
#  138: 'chiptune',
#  139: 'neo soul',
#  140: 'devotional',
#  141: 'krautrock',
#  142: 'roots',
#  143: 'orchestral',
#  144: 'free jazz',
#  145: 'dub techno',
#  146: 'alternative pop',
#  147: 'space',
#  148: 'experimental rock',
#  149: 'electroacoustic',
#  150: 'field recordings',
#  151: 'female vocals',
#  152: 'grindcore',
#  153: 'thrash metal',
#  154: 'neo classical',
#  155: 'leftfield',
#  156: 'metalcore',
#  157: 'coldwave',
#  158: 'afrobeat',
#  159: 'stoner',
#  160: 'melodic',
#  161: 'surf',
#  162: 'space rock',
#  163: 'grime',
#  164: 'groove',
#  165: 'prog',
#  166: 'post metal',
#  167: 'psy trance',
#  168: 'vocal',
#  169: 'gothic',
#  170: 'wave',
#  171: 'tribal',
#  172: 'future bass',
#  173: 'deep techno',
#  174: 'footwork',
#  175: 'synthesizer',
#  176: 'retro',
#  177: 'breakcore',
#  178: 'boogie',
#  179: 'dancehall',
#  180: 'contemporary',
#  181: 'modern classical',
#  182: 'cyberpunk',
#  183: 'thrash',
#  184: 'nu jazz',
#  185: 'improvised ',
#  186: 'balearic',
#  187: 'hard techno',
#  188: 'broken beat',
#  189: 'blues rock',
#  190: 'heavy',
#  191: 'juke',
#  192: 'noise pop',
#  193: 'minimal techno',
#  194: 'queer',
#  195: 'ska',
#  196: 'sludge metal',
#  197: 'glitch hop',
#  198: 'spiritual',
#  199: 'outrun',
#  200: 'beat tape',
#  201: 'folk pop',
#  202: 'folk punk',
#  203: 'uk garage',
#  204: 'microhouse',
#  205: 'prog rock',
#  206: 'stoner metal',
#  207: 'sound art',
#  208: 'industrial techno',
#  209: 'minimalism',
#  210: 'horror',
#  211: 'comedy',
#  212: 'future funk',
#  213: 'tape',
#  214: 'future',
#  215: 'garage punk',
#  216: 'tropical',
#  217: 'acoustic guitar',
#  218: 'afro',
#  219: 'drums',
#  220: 'vinyl',
#  221: 'future beats',
#  222: 'samples',
#  223: 'cumbia',
#  224: 'darksynth',
#  225: 'dreamwave',
#  226: 'lofi hiphop',
#  227: 'progressive house',
#  228: 'bedroom',
#  229: 'heavy rock',
#  230: 'songwriter',
#  231: 'film ',
#  232: 'hip hop instrumentals',
#  233: 'alternative hip hop',
#  234: 'cassette',
#  235: 'harsh noise',
#  236: 'no wave',
#  237: 'french',
#  238: 'contemporary classical',
#  239: 'experimental pop',
#  240: 'dreamy',
#  241: 'dungeon synth',
#  242: 'australian',
#  243: '90s',
#  244: 'live',
#  245: 'crust',
#  246: 'experimental hip hop',
#  247: 'abstract',
#  248: 'surf rock',
#  249: '8bit',
#  250: 'independent',
#  251: 'celtic',
#  252: 'acid house',
#  253: 'soulful',
#  254: 'indie dance',
#  255: 'canadian',
#  256: 'acid techno',
#  257: 'dark techno',
#  258: 'traditional',
#  259: 'ethnic',
#  260: 'funky',
#  261: 'improv',
#  262: 'swing',
#  263: 'classic rock',
#  264: 'italo disco',
#  265: 'christian',
#  266: 'epic',
#  267: 'atmospheric black metal',
#  268: 'drone ambient',
#  269: 'chillhop',
#  270: 'bluegrass',
#  271: 'halftime',
#  272: 'screamo',
#  273: 'uk bass',
#  274: 'italo',
#  275: 'afro house',
#  276: 'jazz fusion',
#  277: 'minimal house',
#  278: 'witch house',
#  279: 'braindance',
#  280: 'djent',
#  281: 'free improvisation',
#  282: 'cover',
#  283: 'detroit techno',
#  284: 'musique concrete',
#  285: 'plunderphonics',
#  286: 'weird',
#  287: 'powerviolence',
#  288: 'gospel',
#  289: 'analog',
#  290: 'fuzz',
#  291: 'dark electro',
#  292: 'power electronics',
#  293: 'minimal synth',
#  294: 'ghettotech',
#  295: 'global bass',
#  296: 'deathcore',
#  297: 'modern jazz',
#  298: 'raw',
#  299: 'irish',
#  300: 'jazz & improvised ',
#  301: 'melodic death metal',
#  302: 'game',
#  303: 'gothic rock',
#  304: 'uk funky',
#  305: 'bay area',
#  306: 'jazzy',
#  307: 'psydub',
#  308: 're edits',
#  309: 'melodic techno',
#  310: 'cosmic',
#  311: 'darkpsy',
#  312: 'jam',
#  313: 'soulful house',
#  314: 'african',
#  315: 'steppers',
#  316: 'grind',
#  317: 'hypnotic',
#  318: 'original',
#  319: 'loops',
#  320: 'poetry',
#  321: 'lounge',
#  322: 'chicago house',
#  323: 'experimental folk',
#  324: 'relaxing',
#  325: 'sci fi',
#  326: 'gabber',
#  327: 'desert rock',
#  328: '140',
#  329: 'psychill',
#  330: 'ethereal',
#  331: 'halloween',
#  332: 'rominimal',
#  333: 'yoga',
#  334: 'cello',
#  335: 'new ',
#  336: 'meditative',
#  337: 'soundsystem',
#  338: 'disco house',
#  339: 'future garage',
#  340: 'minimal wave',
#  341: 'newretrowave',
#  342: 'reggaeton',
#  343: 'deep tech',
#  344: 'instrumental rock',
#  345: 'eclectic',
#  346: 'alt pop',
#  347: 'bassline',
#  348: 'downbeat',
#  349: 'deathrock',
#  350: 'jangle pop',
#  351: 'old school',
#  352: 'chanson',
#  353: 'japanese',
#  354: 'remixes',
#  355: 'lo fi house',
#  356: 'free',
#  357: 'd beat',
#  358: 'art',
#  359: 'phonk',
#  360: 'detroit',
#  361: 'brazilian',
#  362: 'midwest',
#  363: 'percussion',
#  364: 'french pop',
#  365: 'organic',
#  366: 'mashup',
#  367: 'rockabilly',
#  368: 'minimalist',
#  369: 'power metal',
#  370: 'speed metal',
#  371: 'berlin',
#  372: 'vibes',
#  373: 'neofolk',
#  374: 'modular',
#  375: 'brooklyn',
#  376: 'folktronica',
#  377: 'slowcore',
#  378: 'post industrial',
#  379: 'sleep',
#  380: 'psychedelia',
#  381: 'psybient',
#  382: 'kosmische',
#  383: 'japan',
#  384: 'psych rock',
#  385: 'occult',
#  386: 'scottish',
#  387: 'video game',
#  388: 'chamber ',
#  389: 'brutal death metal',
#  390: 'contemporary jazz',
#  391: 'christmas',
#  392: 'art pop',
#  393: 'ritual',
#  394: 'goa trance',
#  395: 'folk metal',
#  396: 'dark disco',
#  397: 'healing',
#  398: 'psychedelic pop',
#  399: 'fantasy',
#  400: 'neuro',
#  401: 'extreme metal',
#  402: 'russian',
#  403: 'sound collage',
#  404: 'scotland',
#  405: 'san francisco',
#  406: 'heavy psych',
#  407: 'alt folk',
#  408: 'relaxation',
#  409: '140bpm',
#  410: 'slowhouse',
#  411: 'technical death metal',
#  412: 'synthpunk',
#  413: 'anime',
#  414: 'chillstep',
#  415: 'industrial metal',
#  416: 'saxophone',
#  417: 'west coast',
#  418: 'violin',
#  419: 'world fusion',
#  420: 'new beat',
#  421: 'acoustic rock',
#  422: 'greek',
#  423: 'acidcore',
#  424: 'hardtek',
#  425: 'hitech',
#  426: 'sample based',
#  427: 'nature',
#  428: 'chanson française',
#  429: 'retro electro',
#  430: 'techno & variations',
#  431: '160',
#  432: 'medieval',
#  433: 'vocaloid',
#  434: 'berlin school',
#  435: 'ambience',
#  436: 'sad',
#  437: 'ambient techno',
#  438: '2step',
#  439: 'death',
#  440: 'royalty free',
#  441: 'hardcore techno',
#  442: 'modular synth',
#  443: 'french touch',
#  444: 'chip',
#  445: 'crossover',
#  446: 'raw black metal',
#  447: 'neurofunk',
#  448: 'kraut',
#  449: 'skate punk',
#  450: 'glam',
#  451: 'baile funk',
#  452: 'tech',
#  453: 'mathcore',
#  454: 'los angeles',
#  455: 'disco edits',
#  456: 'piano solo',
#  457: 'oldskool',
#  458: 'alt rock',
#  459: 'easy listening',
#  460: 'adventurous ',
#  461: 'happy hardcore',
#  462: 'jazz funk',
#  463: 'progressive trance',
#  464: 'country rock',
#  465: 'francophone',
#  466: 'bossa nova',
#  467: 'brasil',
#  468: 'slow',
#  469: 'rework',
#  470: 'dj',
#  471: 'psybass',
#  472: 'ambient dub',
#  473: 'electro house',
#  474: 'modern',
#  475: 'electro swing',
#  476: 'slam',
#  477: 'alternative metal',
#  478: 'digital',
#  479: 'mantra',
#  480: 'tribe',
#  481: 'melodic house & techno',
#  482: 'j pop',
#  483: 'old time',
#  484: '70s',
#  485: 'balkan',
#  486: 'deep dubstep',
#  487: 'melbourne',
#  488: 'worship',
#  489: 'goa',
#  490: 'french house',
#  491: 'dance pop',
#  492: 'soul jazz',
#  493: 'southern rock',
#  494: 'uk garagearage',
#  495: 'midtempo',
#  496: 'political',
#  497: 'ireland',
#  498: 'label',
#  499: 'drumstep',
#  500: 'salsa',
#  501: 'detroit house',
#  502: 'sampling',
#  503: 'oriental',
#  504: 'reissue',
#  505: 'turntablism',
#  506: 'london',
#  507: 'new york',
#  508: 'drumnbass',
#  509: 'baile',
#  510: 'pdx',
#  511: 'rap & hip hop',
#  512: 'ghetto',
#  513: 'steppas',
#  514: 'hauntology',
#  515: 'other',
#  516: 'rocksteady',
#  517: 'big band',
#  518: 'modern funk',
#  519: 'punk hardcore',
#  520: 'swedish',
#  521: '808',
#  522: 'ballad',
#  523: 'party',
#  524: 'speedcore',
#  525: 'uk hip hop',
#  526: 'banjo',
#  527: 'dreampunk',
#  528: 'post black metal',
#  529: 'hybrid',
#  530: 'italian',
#  531: 'chamber pop',
#  532: 'library ',
#  533: 'south african',
#  534: 'generative',
#  535: 'fun',
#  536: 'post vaporwave',
#  537: 'dubwise',
#  538: 'electrofunk',
#  539: 'hard trance',
#  540: 'hardstyle',
#  541: 'feminist',
#  542: 'microsound',
#  543: 'industrial rock',
#  544: 'rock in opposition',
#  545: 'transgender',
#  546: 'symphonic metal',
#  547: 'gqom',
#  548: 'underground rap',
#  549: 'stoner doom',
#  550: 'melodic hardcore',
#  551: 'futurepop',
#  552: 'hiphop rap',
#  553: 'roots rock',
#  554: 'rva',
#  555: 'psy',
#  556: 'forest',
#  557: 'romanian',
#  558: 'nordic',
#  559: 'relapse records',
#  560: 'urban',
#  561: 'black',
#  562: 'liquid drum & bass',
#  563: 'exotica',
#  564: 'video game soundtrack',
#  565: 'deathgrind',
#  566: 'city pop',
#  567: 'emotional',
#  568: 'compilation',
#  569: 'strings',
#  570: 'dark pop',
#  571: 'leftfield house',
#  572: 'uk',
#  573: 'uk hardcore',
#  574: 'jazz rock',
#  575: 'nu funk',
#  576: 'love',
#  577: 'background ',
#  578: '2020',
#  579: 'street',
#  580: 'avant pop',
#  581: 'funky house',
#  582: 'reedit',
#  583: 'old school death metal',
#  584: 'darkprog',
#  585: 'nz',
#  586: 'psych folk',
#  587: 'math',
#  588: 'rare groove',
#  589: 'twee',
#  590: 'protest',
#  591: 'fiddle',
#  592: 'electroclash',
#  593: 'baltimore club',
#  594: 'synthwave 80s',
#  595: 'trad',
#  596: 'ost',
#  597: 'dream',
#  598: 'g funk',
#  599: 'miami bass',
#  600: 'skramz',
#  601: 'country folk',
#  602: 'ethno',
#  603: 'tribecore',
#  604: 'blackened death metal',
#  605: 'wonky',
#  606: 'techstep',
#  607: '1980s',
#  608: 'gothic metal',
#  609: 'guitar pop',
#  610: 'riddim',
#  611: 'inspirational',
#  612: 'hard drum',
#  613: 'outsider',
#  614: 'nerdcore',
#  615: 'kpop',
#  616: 'icelandic',
#  617: 'blackgaze',
#  618: 'samba',
#  619: 'trash',
#  620: 'sound healing',
#  621: 'chicago',
#  622: 'garage pop',
#  623: 'psybreaks',
#  624: 'freak folk',
#  625: 'norwegian',
#  626: 'hip hop soul',
#  627: 'frenchcore',
#  628: 'electronic rock',
#  629: 'chopped & screwed',
#  630: '4x4',
#  631: 'lgbt',
#  632: 'goregrind',
#  633: 'vintage',
#  634: 'hip hop (real shit)',
#  635: 'symphonic',
#  636: 'ghetto house',
#  637: 'hard',
#  638: 'cosmic disco',
#  639: 'mallsoft',
#  640: 'aggrotech',
#  641: 'songs',
#  642: 'minimal dub',
#  643: 'scottish indie',
#  644: 'honky tonk',
#  645: 'lyrical',
#  646: 'backing track',
#  647: 'micro',
#  648: 'lowercase',
#  649: 'ambient folk',
#  650: 'horror punk',
#  651: 'death doom',
#  652: 'netlabel',
#  653: 'dance punk',
#  654: 'ketapop',
#  655: 'afro latin',
#  656: '1990s',
#  657: 'psychedelic folk',
#  658: 'moog',
#  659: 'germany',
#  660: 'latin jazz',
#  661: 'ambient drone',
#  662: 'desert',
#  663: 'seattle',
#  664: 'berlin techno',
#  665: 'drumandbass',
#  666: 'athens',
#  667: 'producer',
#  668: 'electro industrial',
#  669: 'canadiana',
#  670: 'latino',
#  671: 'solo piano',
#  672: 'underground house',
#  673: 'ghetto funk',
#  674: 'esoteric',
#  675: 'world bass',
#  676: 'nocturnal',
#  677: 'vapour',
#  678: 'anti folk',
#  679: 'storytelling',
#  680: 'energy',
#  681: 'japanese pop',
#  682: 'melodic metal',
#  683: 'funk soul',
#  684: 'fourth world',
#  685: 'crust punk',
#  686: 'street punk',
#  687: 'chillhouse',
#  688: 'trans',
#  689: 'flute',
#  690: 'sample pack',
#  691: 'bossa',
#  692: 'indie punk',
#  693: '24bit',
#  694: 'dubstep & electronic',
#  695: 'trippy',
#  696: 'dmv',
#  697: 'uk techno',
#  698: 'melancholic',
#  699: 'halftime drum & bass',
#  700: 'abstract hip hop',
#  701: 'j core',
#  702: 'scratch',
#  703: 'nwobhm',
#  704: 'medicine ',
#  705: 'solo',
#  706: 'post dubstep',
#  707: 'riot grrrl',
#  708: 'technopop',
#  709: 'indie rap',
#  710: 'beatdown',
#  711: 'music for youtube',
#  712: 'speed garage',
#  713: 'no copyright ',
#  714: 'noisecore',
#  715: 'iron lung records',
#  716: 'ritual ambient',
#  717: 'afrofuturism',
#  718: 'nwothm',
#  719: 'ambient rock',
#  720: 'romanian techno',
#  721: 'classic',
#  722: 'dysto',
#  723: 'anarcho punk',
#  724: 'organic electronic',
#  725: 'disco punk',
#  726: 'jazzhop',
#  727: 'progressive chill',
#  728: 'analogue',
#  729: 'dubtech',
#  730: 'country blues',
#  731: 'united kingdom',
#  732: 'sequencer',
#  733: 'shred',
#  734: 'psytechno',
#  735: 'cassette tape',
#  736: 'franco',
#  737: 'iron lung',
#  738: 'b boy breaks',
#  739: 'electronic pop',
#  740: 'greatest label of all time',
#  741: 'indus',
#  742: '160bpm',
#  743: 'nintendo',
#  744: 'podcasts',
#  745: 'pop folk',
#  746: 'afro brazilian',
#  747: 'pagan',
#  748: 'electro bass',
#  749: 'doo wop',
#  750: 'juke footwork',
#  751: 'hypnotic techno',
#  752: 'chant',
#  753: 'scottish folk',
#  754: 'surf punk',
#  755: 'conscious hip hop',
#  756: 'mpb',
#  757: 'sound design',
#  758: 'turkish',
#  759: 'funeral doom',
#  760: 'ragga',
#  761: 'irish folk',
#  762: 'shamanic',
#  763: 'soulection',
#  764: 'dutch',
#  765: 'fashion ',
#  766: 'organic house',
#  767: 'sound effects',
#  768: 'mutant bass',
#  769: 'chinese',
#  770: 'memphis',
#  771: 'singer',
#  772: 'tango',
#  773: 'no copyright sounds',
#  774: 'big beat',
#  775: 'swiss',
#  776: 'internet',
#  777: 'deutschrap',
#  778: 'dark synthwave',
#  779: 'tribal house',
#  780: 'western',
#  781: 'female',
#  782: 'diy record label',
#  783: 'kwaito',
#  784: 'slow jams',
#  785: 'rub a dub',
#  786: 'appalachian',
#  787: 'retrosynth',
#  788: 'computer ',
#  789: 'full on',
#  790: 'royalty free beats',
#  791: 'slushwave',
#  792: 'chanson francophone',
#  793: 'folk blues',
#  794: 'hymns',
#  795: 'scandinavian',
#  796: 'elektro',
#  797: 'concept album',
#  798: 'raggatek',
#  799: 'welsh',
#  800: 'forest psy trance',
#  801: 'gabba',
#  802: 'folklore',
#  803: 'brazil',
#  804: 'toronto',
#  805: 'fastcore',
#  806: 'afro soul',
#  807: 'riffs',
#  808: 'holiday',
#  809: 'trailer ',
#  810: 'trumpet',
#  811: 'epic metal',
#  812: 'progressive psy trance',
#  813: 'synth rock',
#  814: 'jam band',
#  815: 'eccojams',
#  816: 'indie pop rock',
#  817: 'hiphop instrumental',
#  818: 'futuristic',
#  819: 'neo psychedelia',
#  820: 'composition',
#  821: 'leftfield bass',
#  822: 'guitar solo',
#  823: 'lo fi pop',
#  824: 'boston',
#  825: 'minimal deep tech',
#  826: 'outsider house',
#  827: 'rhythm game',
#  828: 'polish',
#  829: 'post everything',
#  830: 'depressive black metal',
#  831: 'oakland',
#  832: 'sub pop',
#  833: 'israeli',
#  834: 'psygressive',
#  835: 'sad bastard ',
#  836: 'traditional jazz',
#  837: 'tape loops',
#  838: 'modern rock',
#  839: 'wavy',
#  840: 'slamming brutal death metal',
#  841: 'fieldrecording',
#  842: 'psyche',
#  843: 'canadian metal',
#  844: 'alfa matrix',
#  845: 'indian',
#  846: 'ep',
#  847: 'depressive suicidal black metal',
#  848: 'melodic black metal',
#  849: 'traditional folk',
#  850: 'middle eastern',
#  851: 'goth rock',
#  852: 'post classical',
#  853: 'creative commons',
#  854: 'multi genre',
#  855: 'ambient house',
#  856: 'jam track',
#  857: 'psytech',
#  858: 'mix',
#  859: 'cumbia digital',
#  860: 'free techno',
#  861: 'c86',
#  862: 'dark folk',
#  863: 'darkpsy trance',
#  864: 'deep progressive',
#  865: 'groove metal',
#  866: 'quebecois',
#  867: 'hard house',
#  868: 'zenonesque',
#  869: 'romanian minimal',
#  870: 'house techno',
#  871: 'afropop',
#  872: 'popindie',
#  873: 'video game remix',
#  874: 'free samples',
#  875: 'free improv',
#  876: 'underground hip hip',
#  877: 'movie',
#  878: 'psych pop',
#  879: 'bootleg',
#  880: 'indie classical',
#  881: 'progressive death metal',
#  882: 'nostalgic',
#  883: 'childrens ',
#  884: 'bubblegum',
#  885: 'melodic punk',
#  886: 'amen',
#  887: 'american primitive',
#  888: 'new orleans jazz',
#  889: 'fingerstyle',
#  890: 'female fronted',
#  891: 'sound',
#  892: 'alien',
#  893: 'analog synthesizer',
#  894: 'quiet',
#  895: 'roots reggae',
#  896: 'oi',
#  897: 'post rock instrumental',
#  898: 'cerebral',
#  899: 'cold',
#  900: 'austin',
#  901: 'dub house',
#  902: 'finnish',
#  903: 'atmospheric metal',
#  904: 'duo',
#  905: 'queercore',
#  906: 'punk pop',
#  907: '90s house',
#  908: 'electropunk',
#  909: 'africa',
#  910: 'hyperpop',
#  911: 'technical metal',
#  912: 'ragga jungle',
#  913: 'soul hip hop',
#  914: 'footwork jungle',
#  915: 'beautiful',
#  916: 'vaporfunk',
#  917: 'post grunge',
#  918: 'deep drum & bass',
#  919: 'razor & tape',
#  920: 'everything',
#  921: 'ska punk',
#  922: 'shoegazer',
#  923: 'acid folk',
#  924: 'smooth jazz',
#  925: 'bboy',
#  926: 'hard dance',
#  927: 'ghettotek',
#  928: 'crossover thrash',
#  929: 'hnw',
#  930: 'expiremental',
#  931: 'space bass',
#  932: 'extreme',
#  933: 'hightech',
#  934: 'brass',
#  935: 'game soundtrack',
#  936: 'drumfunk',
#  937: 'monstercat',
#  938: 'pacific northwest',
#  939: 'film score',
#  940: 'clan destine records',
#  941: 'tropicalia',
#  942: 'hebrew',
#  943: 'modern metal',
#  944: 'clan destine traxx',
#  945: 'clan destine',
#  946: 'deutschpunk',
#  947: 'chillrave',
#  948: 'progressive chillout',
#  949: 'deep disco',
#  950: '60s',
#  951: 'audiobooks',
#  952: 'dark punk',
#  953: 'mambo',
#  954: 'oi!',
#  955: 'emoviolence',
#  956: 'tribute',
#  957: 'indietronica',
#  958: 'ragtime',
#  959: 'minimal tech',
#  960: 'kuduro',
#  961: 'futuresynth',
#  962: 'drill',
#  963: 'vaportrap',
#  964: 'electro soul',
#  965: 'soundlibraries',
#  966: 'peaceful',
#  967: 'geek rock',
#  968: 'cosmic jazz',
#  969: 'ccm',
#  970: 'southern',
#  971: 'paris',
#  972: 'psychobilly',
#  973: 'kids',
#  974: 'muslimgauze',
#  975: 'rhythmic noise',
#  976: 'intelligent',
#  977: 'avante garde',
#  978: 'bass house',
#  979: 'geek',
#  980: 'bagpipes',
#  981: 'magic',
#  982: 'kirtan',
#  983: 'staalplaat',
#  984: 'krump',
#  985: 'classic house',
#  986: 'live electronics',
#  987: 'cover song',
#  988: 'dark electronic',
#  989: 'vocal jazz',
#  990: 'vlog ',
#  991: 'whatever',
#  992: 'tropical bass',
#  993: 'old school dungeon synth',
#  994: 'global',
#  995: 'musical',
#  996: 'improvisational',
#  997: 'home recording',
#  998: 'electro dub',
#  999: 'hot jazz',
#  ...}

# %%
edge_reader = pd.read_csv(edge_file)
# edge_reader = edge_reader.sort_values(['location', "genre1"], ascending = (True, False))
edge_reader
# Out:
#               genre1       genre2  count                location
# 0            ambient  atmospheric     18  Adelaide SA, Australia
# 1            ambient  electronica     29  Adelaide SA, Australia
# 2        atmospheric  electronica     10  Adelaide SA, Australia
# 3                ebm   electronic     28  Adelaide SA, Australia
# 4                ebm  electronica     23  Adelaide SA, Australia
# ...              ...          ...    ...                     ...
# 382717         space       stoner      1        İstanbul, Turkey
# 382718         space  stoner rock      1        İstanbul, Turkey
# 382719       ambient   industrial      1        İstanbul, Turkey
# 382720       ambient       techno      1        İstanbul, Turkey
# 382721  experimental   soundscape      1        İstanbul, Turkey
#
# [382722 rows x 4 columns]

# %% [markdown]
# # 3. produce json file from the edge and node sheet

# %%
json_file = "/Users/geistling/Documents/1_Projects/bandcamp/bandcamp_viz/data/network_graph.json"

# %%
# Attempt to order by most common genre in city

# group link_reader data and tally up occurences of genres in "genre1" and "genre2"
lr = pd.read_csv(edge_file)

grouped2 = lr.groupby('location')
city_genre_tally = pd.DataFrame(columns = ['index','rank','total','location'])
for place, group in grouped2:
    df1 = pd.DataFrame(group['genre1'].value_counts())
    df2 = pd.DataFrame(group['genre2'].value_counts())
    dfc = pd.concat([df1, df2], axis=1, sort=False)
    # place
    dfc["total"] = dfc.sum(axis=1)
    dfc = dfc.sort_values(['total'], ascending = (False))
    dfc['location'] = place
    dfc = dfc.reset_index()
    dfc['rank'] = dfc.index
    city_genre_tally = pd.concat([city_genre_tally, dfc], axis=0, sort=False)

# %%
def order_lookup(genre1, genre2, city):
    # return rows for genre1 and genre2 in city_genre_tally for appropriate city
    # the genre that's a smaller rank becomes gen1
    genmatch1 = city_genre_tally.loc[(
        city_genre_tally['index'] == genre1) & (city_genre_tally['location'] == city
                                                ), "rank"]
    genmatch2 = city_genre_tally.loc[(
        city_genre_tally['index'] == genre2) & (city_genre_tally['location'] == city
                                                ), "rank"]
    if genmatch1.values > genmatch2.values:
        gen1 = genre2
        gen2 = genre1
    else:
        gen1 = genre1
        gen2 = genre2
    g1 = genre_lookup(place_obj, gen1)
    g2 = genre_lookup(place_obj, gen2)
    return (g1, g2)

# %% [raw]
# with open(json_file, "r") as jsonFile:
#     json_output = json.load(jsonFile)
# node_reader = pd.read_csv(node_file)
# # order rows so most frequent genres have the smallest numbers
# node_reader = node_reader.sort_values(['location', "count"], ascending = (True, False))
#
#
# def genre_lookup(place_obj, genre):
#     node_match = [node for node in alias_json if node['g'] == genre]
#     return node_match[0]["i"]
#
# for row in node_reader.itertuples():
#     place_obj = {'n':[], 'l':[], 'w': 1}
#     place_matches = [obj for obj in json_output if obj['ct'] == row.location]
#     if not place_matches:
#         place_obj['ct'] = row.location
#         place_obj['cor'] = [row.lng, row.lat]
#         json_output.append(place_obj)
#     elif place_matches:
#         place_obj = place_matches[0]
#     g = genre_lookup(place_obj, row.genre)
#     place_obj["n"].append({"g":g,"c":row.count,"r":round(row.relative, 3)}) #"i":node_id,
#
# link_reader = pd.read_csv(edge_file)
#
# for row in link_reader.itertuples():
#     place_matches = [obj for obj in json_output if obj['ct'] == row.location]
#     # troubleshoots match issues
#     if not place_matches:
#         print(row)
#     place_obj = place_matches[0]
# #     g1, g2 = order_lookup(row.genre1, row.genre2, row.location)
#     g1 = genre_lookup(place_obj, row.genre1)
#     g2 = genre_lookup(place_obj, row.genre2)
#     genre_matches = [obj for obj in place_obj['l'] if obj['s'] == g1]
#     if not genre_matches:
#         gm = {'s': g1, 'ts': []}
#         place_obj['l'].append(gm)
#     elif genre_matches:
#         gm = genre_matches[0]
#     gm['ts'].append({'t': g2, "c":row.count})
#     if row.count > place_obj["w"]:
#         place_obj["w"] = row.count
# #     place_obj["l"].append({"s":g1,"t":g2,"c":row.count})
#
# with open(json_file, "w") as jsonFile:
#     json.dump(json_output, jsonFile, separators=(',', ':'))
